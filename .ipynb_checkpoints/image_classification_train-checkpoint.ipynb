# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Class labels for CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 
               'dog', 'frog', 'horse', 'ship', 'truck']

# Display the first 20 images with their true labels
plt.figure(figsize=(20, 10))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i])
    true_label = test_labels[i][0]
    plt.xlabel(f"{i}: {class_names[true_label]}")
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.6776 - accuracy: 0.7665 - val_loss: 0.6584 - val_accuracy: 0.7726
# Epoch 2/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.6735 - accuracy: 0.7686 - val_loss: 0.6419 - val_accuracy: 0.7762
# Epoch 3/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6667 - accuracy: 0.7709 - val_loss: 0.7227 - val_accuracy: 0.7517
# Epoch 4/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.6667 - accuracy: 0.7710 - val_loss: 0.6464 - val_accuracy: 0.7763
# Epoch 5/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6691 - accuracy: 0.7682 - val_loss: 0.6328 - val_accuracy: 0.7852
# Epoch 6/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6607 - accuracy: 0.7715 - val_loss: 0.6699 - val_accuracy: 0.7740
# Epoch 7/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.6612 - accuracy: 0.7724 - val_loss: 0.7071 - val_accuracy: 0.7574
# Epoch 8/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.6582 - accuracy: 0.7739 - val_loss: 0.6182 - val_accuracy: 0.7890
# Epoch 9/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6494 - accuracy: 0.7771 - val_loss: 0.6209 - val_accuracy: 0.7896
# Epoch 10/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6582 - accuracy: 0.7746 - val_loss: 0.6236 - val_accuracy: 0.7889
# Epoch 11/20
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.6505 - accuracy: 0.7765 - val_loss: 0.6206 - val_accuracy: 0.7895
# Epoch 12/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.6464 - accuracy: 0.7769 - val_loss: 0.6567 - val_accuracy: 0.7762
# Epoch 13/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6442 - accuracy: 0.7791 - val_loss: 0.6115 - val_accuracy: 0.7872
# Epoch 14/20
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.6433 - accuracy: 0.7799 - val_loss: 0.7083 - val_accuracy: 0.7587
# Epoch 15/20
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.6340 - accuracy: 0.7806 - val_loss: 0.6703 - val_accuracy: 0.7735
# Epoch 16/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6391 - accuracy: 0.7780 - val_loss: 0.6261 - val_accuracy: 0.7859
# Epoch 17/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6311 - accuracy: 0.7825 - val_loss: 0.6514 - val_accuracy: 0.7789
# Epoch 18/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6356 - accuracy: 0.7816 - val_loss: 0.6201 - val_accuracy: 0.7891
# Epoch 19/20
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.6303 - accuracy: 0.7824 - val_loss: 0.6430 - val_accuracy: 0.7848
# Epoch 20/20
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.6316 - accuracy: 0.7826 - val_loss: 0.6410 - val_accuracy: 0.7825

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("\nTest accuracy:", test_acc)
# Out:
# 313/313 - 4s - loss: 0.7296 - accuracy: 0.7434 - 4s/epoch - 14ms/step
#
# Test accuracy: 0.743399977684021

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Select an image from the test dataset
image_index = 8  # Change the index to test with different images
img = test_images[image_index]
true_label = test_labels[image_index][0]

# Display the selected image
plt.imshow(img)
plt.title(f"True label: {class_names[true_label]}")
plt.show()

# Add a batch dimension
img = np.expand_dims(img, axis=0)

# Predict the class of the image
predictions = model.predict(img)
predicted_class = np.argmax(predictions, axis=1)

# Print the predicted class
print(f"Predicted class: {class_names[predicted_class[0]]}")
# Out:
# 1/1 [==============================] - 0s 63ms/step
# Predicted class: cat
